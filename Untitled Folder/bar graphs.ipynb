# %%
import matplotlib.pyplot as plt
import numpy as np
 
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
x_pos = np.arange(len(objects))
print(x_pos)

performance = [10,8,6,4,2,1]

plt.plot(x_pos, performance)#, ".-")
#plt.bar(x_pos, performance)
plt.xticks(x_pos, objects)

 
plt.show()
# Out:
# [0 1 2 3 4 5]

# %% [markdown]
# **HI**
#
# ```python
# def function(name):
# ```
